# %%
import cv2
paper = cv2.imread('strawberry copy.jpeg', cv2.IMREAD_COLOR)
#cv2.startWindowThread()
#cv2.imshow('1', paper)
#cv2.waitKey(0)
h, w = paper.shape[:2]
print(h, w)
#cv2.imwrite('1.jpg', paper)
#cv2.destroyWindow('1')
# Out:
# 2448 3264

# %%
b, g, r = cv2.split(paper)

# %%
r.flatten()
# Out:
# array([ 32,  31,  31, ..., 247, 244, 245], dtype=uint8)

# %%
hist(r.flatten(), 25)
# Out:
# (array([ 11989., 237806., 230857., 425252., 422789., 410793., 445518.,
#         384153., 335631., 268339., 299597., 284955., 262908., 231528.,
#         247423., 267035., 258100., 235420., 227457., 249726., 423806.,
#         652930., 575673., 318523., 282064.]),
#  array([  6.  ,  15.96,  25.92,  35.88,  45.84,  55.8 ,  65.76,  75.72,
#          85.68,  95.64, 105.6 , 115.56, 125.52, 135.48, 145.44, 155.4 ,
#         165.36, 175.32, 185.28, 195.24, 205.2 , 215.16, 225.12, 235.08,
#         245.04, 255.  ]),
#  <a list of 25 Patch objects>)

# %%
from PIL import Image
from pylab import *
paper2 = Image.open('strawberry copy.jpeg')
imshow(paper2)

# %%
b, g, r = cv2.split(paper)
histImgB = calcAndDrawHist(b, [255, 0, 0])  
histImgG = calcAndDrawHist(g, [0, 255, 0])  
histImgR = calcAndDrawHist(r, [0, 0, 255])  
      
cv2.imshow("histImgB", histImgB)  
cv2.imshow("histImgG", histImgG)  
cv2.imshow("histImgR", histImgR)  
cv2.imshow("Img", img)  
cv2.waitKey(0)  
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c45c733e5dbe> in <module>()
#       1 b, g, r = cv2.split(paper)
# ----> 2 histImgB = calcAndDrawHist(b, [255, 0, 0])
#       3 histImgG = calcAndDrawHist(g, [0, 255, 0])
#       4 histImgR = calcAndDrawHist(r, [0, 0, 255])
#       5
#
# NameError: name 'calcAndDrawHist' is not defined
