# %%
#Part 2
#image0
import cv2
from PIL import Image
from pylab import *
import os
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import optimize


aB, kB = 1.0778522674049973, 8.32113999783056
aG, kG = 0.901618912218898,  7.671267000584436
aR, kR = 0.8515554253949513, 7.489557178804966
image0 = cv2.imread('set/SAM_4040.jpeg', cv2.IMREAD_COLOR)
b0, g0, r0 = cv2.split(image0)
bf0 = b0.flatten()
gf0 = g0.flatten()
rf0 = r0.flatten()
print(bf0)
bf0G = bf0 ** (1 / aB)
gf0G = gf0 ** (1 / aG)
rf0G = rf0 ** (1 / aR)
print(bf0G)
brightnessB0G = (sum(bf0) / len(bf0)) ** (1 / aB)
brightnessG0G = (sum(gf0) / len(gf0)) ** (1 / aG)
brightnessR0G = (sum(rf0) / len(rf0)) ** (1 / aR)
print(int(brightnessB0G), int(brightnessG0G), int(brightnessR0G))
hist(bf0G, 25, facecolor = 'blue')
plt.show()
hist(gf0G, 25, facecolor = 'green')
plt.show()
hist(rf0G, 25, facecolor = 'red')
plt.show()
# Out:
# [12 13 13 ...  2  2  2]
# [10.02843093 10.80150471 10.80150471 ...  1.90233448  1.90233448
#   1.90233448]
# 30 63 82

# %%
#image1
image1 = cv2.imread('set/SAM_4046.jpeg', cv2.IMREAD_COLOR)
b1, g1, r1 = cv2.split(image1)
bf1 = b1.flatten()
gf1 = g1.flatten()
rf1 = r1.flatten()
bf1G = bf1 ** (1 / aB)
gf1G = gf1 ** (1 / aG)
rf1G = rf1 ** (1 / aR)
print(bf1G)
brightnessB1 = (sum(bf1) / len(bf1)) ** (1 / aB)
brightnessG1 = (sum(gf1) / len(gf1)) ** (1 / aG)
brightnessR1 = (sum(rf1) / len(rf1)) ** (1 / aR)
print(int(brightnessB1), int(brightnessG1), int(brightnessR1))
hist(bf1G, 25, facecolor = 'blue')
plt.show()
hist(gf1G, 25, facecolor = 'green')
plt.show()
hist(rf1G, 25, facecolor = 'red')
plt.show()
# Out:
# [39.08931115 39.08931115 39.08931115 ...  6.88431346  6.88431346
#   6.88431346]
# 54 125 170

# %%
#image2
image2 = cv2.imread('set/SAM_4060.jpeg', cv2.IMREAD_COLOR)
b2, g2, r2 = cv2.split(image2)
bf2 = b2.flatten()
gf2 = g2.flatten()
rf2 = r2.flatten()
bf2G = bf2 ** (1 / aB)
gf2G = gf2 ** (1 / aG)
rf2G = rf2 ** (1 / aR)
brightnessB2 = (sum(bf2) / len(bf2)) ** (1 / aB)
brightnessG2 = (sum(gf2) / len(gf2)) ** (1 / aG)
brightnessR2 = (sum(rf2) / len(rf2)) ** (1 / aR)
print(int(brightnessB2), int(brightnessG2), int(brightnessR2))
hist(bf2G, 25, facecolor = 'blue')
plt.show()
hist(gf2G, 25, facecolor = 'green')
plt.show()
hist(rf2G, 25, facecolor = 'red')
plt.show()
# Out:
# 144 394 566

# %%
#B'g/a1
a1 = 4
bf1GDivideA1 = bf1 ** (1 / aB) / a1
gf1GDivideA1 = gf1 ** (1 / aG) / a1
rf1GDivideA1 = rf1 ** (1 / aR) / a1
hist(bf1GDivideA1, 25, facecolor = 'blue')
plt.show()
hist(gf1GDivideA1, 25, facecolor = 'green')
plt.show()
hist(rf1GDivideA1, 25, facecolor = 'red')
plt.show()

# %%
#B'g/a2
a2 = 100
bf2GDivideA2 = bf2 ** (1 / aB) / a2
gf2GDivideA2 = gf2 ** (1 / aG) / a2
rf2GDivideA2 = rf2 ** (1 / aR) / a2
hist(bf2GDivideA2, 25, facecolor = 'blue')
plt.show()
hist(gf2GDivideA2, 25, facecolor = 'green')
plt.show()
hist(rf2GDivideA2, 25, facecolor = 'red')
plt.show()

# %%
#Part 3
#algorithm 1
hdr1B = [[0] * 5472 for _ in range(3648)]
print(len(hdr1B[1]))
f = 0
for i in range(len(hdr1B)):
    for j in range(len(hdr1B[0])):
        if bf2GDivideA2[f] < 255:
            hdr1B[i][j] = bf2GDivideA2[f]
        if bf1GDivideA1[f] < 255:
            hdr1B[i][j] = bf1GDivideA1[f]
        if bf0G[f] < 255:
            hdr1B[i][j] = bf0G
        f += 1
# Out:
# 5472

# %%
hdr1BA = array(hdr1B, 'f')
hdr1BF = hdr1BA.flatten()
#hist(hdr1B, 25, facecolor = 'blue')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-781ca96748b8> in <module>()
# ----> 1 hdr1BA = array(hdr1B, 'f')
#       2 hdr1BF = hdr1BA.flatten()
#       3 #hist(hdr1B, 25, facecolor = 'blue')
#
# MemoryError:

# %%
hist(hdr1BF, 25, facecolor = 'blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-705816c7b03f> in <module>()
# ----> 1 hist(hdr1BF, 25, facecolor = 'blue')
#
# NameError: name 'hdr1BF' is not defined

# %%
#hdr1 green
hdr1G = [[0] * 5472 for _ in range(3648)]
print(len(hdr1G[1]))
f = 0
for i in range(len(hdr1G)):
    for j in range(len(hdr1G[0])):
        if gf2GDivideA2[f] < 255:
            hdr1G[i][j] = gf2GDivideA2[f]
        if gf1GDivideA1[f] < 255:
            hdr1G[i][j] = gf1GDivideA1[f]
        if gf0G[f] < 255:
            hdr1G[i][j] = gf0G[f]
        f += 1
# Out:
# 5472

# %%
hdr1GA = array(hdr1G, 'f')
hdr1GF = hdr1GA.flatten()

# %%
hist(hdr1GF, 25, facecolor = 'blue')
# Out:
# (array([9706836., 2669690.,  826161.,  757446.,  530295.,  398686.,
#          297177.,  266599.,  265465.,  270997.,  363130., 2330882.,
#          187652.,  133163.,  114152.,  164014.,  136163.,  144144.,
#          101755.,   94530.,   56653.,   43425.,   42400.,   29367.,
#           31074.]),
#  array([  0.      ,  10.135996,  20.271992,  30.407986,  40.543983,
#          50.679977,  60.81597 ,  70.951965,  81.08797 ,  91.22396 ,
#         101.359955, 111.49595 , 121.63194 , 131.76794 , 141.90393 ,
#         152.03993 , 162.17593 , 172.31192 , 182.44792 , 192.58391 ,
#         202.71991 , 212.85591 , 222.9919  , 233.1279  , 243.26389 ,
#         253.39989 ], dtype=float32),
#  <a list of 25 Patch objects>)

# %%
#hdr1 red
hdr1R = [[0] * 5472 for _ in range(3648)]
print(len(hdr1R[1]))
f = 0
for i in range(len(hdr1R)):
    for j in range(len(hdr1R[0])):
        if rf2GDivideA2[f] < 255:
            hdr1R[i][j] = rf2GDivideA2[f]
        if rf1GDivideA1[f] < 255:
            hdr1R[i][j] = rf1GDivideA1[f]
        if rf0G[f] < 255:
            hdr1R[i][j] = rf0G[f]
        f += 1
# Out:
# 5472

# %%
hdr1RA = array(hdr1R, 'f')
hdr1RF = hdr1RA.flatten()

# %%
hist(hdr1RF, 25, facecolor = 'red')
# Out:
# (array([8494715., 3383296.,  921455.,  563882.,  471554.,  410370.,
#          278706.,  295879.,  218906.,  261420.,  201968.,  202657.,
#          271178.,  409827.,  389541.,  658261., 1948700.,   90378.,
#           76070.,   67230.,   62909.,   63671.,   71515.,   72309.,
#           75459.]),
#  array([  0.      ,  10.197675,  20.39535 ,  30.593023,  40.7907  ,
#          50.988373,  61.186047,  71.38372 ,  81.5814  ,  91.77907 ,
#         101.976746, 112.17442 , 122.37209 , 132.56976 , 142.76744 ,
#         152.96512 , 163.1628  , 173.36047 , 183.55814 , 193.75581 ,
#         203.95349 , 214.15117 , 224.34885 , 234.54651 , 244.74419 ,
#         254.94186 ], dtype=float32),
#  <a list of 25 Patch objects>)

# %%
item = cv2.merge((hdr1BA, hdr1GA, hdr1RA))

imshow(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b56001e4eccc> in <module>()
# ----> 1 item = cv2.merge((hdr1BA, hdr1GA, hdr1RA))
#       2
#       3 imshow(item)
#
# NameError: name 'hdr1BA' is not defined

# %%
#algorithm 2
